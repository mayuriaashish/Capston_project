# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
## Read the CSV file 
df1 = pd.read_csv("C:/Users/Mohit Lahoti/Downloads/Compressed/movie_name.csv")

# %%
df1
# Out:
#         SNO                                         Movie Name  \
# 0         1                                    The Dark Knight
# 1         2      The Lord of the Rings: The Return of the King
# 2         3                Spider-Man: Across the Spider-Verse
# 3         4                                          Inception
# 4         5  The Lord of the Rings: The Fellowship of the Ring
# ...     ...                                                ...
# 1745  1,746                                               Krym
# 1746  1,747                                          Barb Wire
# 1747  1,748              Spy Kids 4: All the Time in the World
# 1748  1,749                                              D-War
# 1749  1,750                                           Catwoman
#
#           Director Name1 Director Name2       Director Name3 Duration  \
# 0      Christopher Nolan            NaN                  NaN  152 min
# 1          Peter Jackson            NaN                  NaN  201 min
# 2     Joaquim Dos Santos    Kemp Powers   Justin K. Thompson  140 min
# 3      Christopher Nolan            NaN                  NaN  148 min
# 4          Peter Jackson            NaN                  NaN  178 min
# ...                  ...            ...                  ...      ...
# 1745     Aleksey Pimanov            NaN                  NaN   99 min
# 1746         David Hogan            NaN                  NaN   98 min
# 1747    Robert Rodriguez            NaN                  NaN   89 min
# 1748      Hyung-rae Shim            NaN                  NaN  107 min
# 1749               Pitof            NaN                  NaN  104 min
#
#           Year  Rating  Metascore
# 0         2008     9.0       84.0
# 1         2003     9.0       94.0
# 2         2023     8.9       86.0
# 3         2010     8.8       74.0
# 4         2001     8.8       92.0
# ...        ...     ...        ...
# 1745  I) (2017     3.6        NaN
# 1746      1996     3.5       40.0
# 1747      2011     3.5       37.0
# 1748      2007     3.5       33.0
# 1749      2004     3.4       27.0
#
# [1750 rows x 9 columns]

# %%
df1.columns
# Out:
# Index(['SNO', 'Movie Name', 'Director Name1', 'Director Name2',
#        'Director Name3', 'Duration', 'Year', 'Rating', 'Metascore'],
#       dtype='object')

# %%
## Read the CSV file 
df2 = pd.read_csv("C:/Users/Mohit Lahoti/Downloads/Compressed/stars_name.csv")

# %%
df2
# Out:
#                                              Movie Name        Stars Name1  \
# 0                                       The Dark Knight     Christian Bale
# 1         The Lord of the Rings: The Return of the King        Elijah Wood
# 2                   Spider-Man: Across the Spider-Verse      Shameik Moore
# 3                                             Inception  Leonardo DiCaprio
# 4     The Lord of the Rings: The Fellowship of the Ring        Elijah Wood
# ...                                                 ...                ...
# 1746                                               Krym      Roman Kurtsyn
# 1747                                          Barb Wire    Pamela Anderson
# 1748              Spy Kids 4: All the Time in the World       Jessica Alba
# 1749                                              D-War         Jason Behr
# 1750                                                NaN     Christian Bale
#
#                 Stars Name2         Stars Name3         Stars Name4  \
# 0              Heath Ledger       Aaron Eckhart       Michael Caine
# 1           Viggo Mortensen        Ian McKellen       Orlando Bloom
# 2          Hailee Steinfeld   Brian Tyree Henry   Luna Lauren Velez
# 3      Joseph Gordon-Levitt         Elliot Page        Ken Watanabe
# 4              Ian McKellen       Orlando Bloom           Sean Bean
# ...                     ...                 ...                 ...
# 1746        Evgeniya Lapova       Pavel Kraynov      Pavel Trubiner
# 1747          Amir AboulEla   Adriana Alexander      David Andriole
# 1748           Jeremy Piven         Joel McHale     Rowan Blanchard
# 1749          Amanda Brooks      Robert Forster      Craig Robinson
# 1750                    NaN                 NaN                 NaN
#
#           Votes     Genre1               Genre2                  Genre3  \
# 0     2,739,255     Action                Crime       Drama
# 1     1,898,117     Action            Adventure       Drama
# 2       182,431  Animation               Action   Adventure
# 3     2,430,810     Action            Adventure      Sci-Fi
# 4     1,926,549     Action            Adventure       Drama
# ...         ...        ...                  ...                     ...
# 1746     33,496     Action    Drama                                 NaN
# 1747     30,451     Action   Sci-Fi                                 NaN
# 1748     27,159     Action            Adventure      Comedy
# 1749     25,068     Action                Drama     Fantasy
# 1750        NaN        NaN                  NaN                     NaN
#
#      Gross Collection  Popularity Certification  Unnamed: 12
# 0            $534.86M         9.0            UA          NaN
# 1            $377.85M         9.0             U          NaN
# 2               *****         8.9             U          NaN
# 3            $292.58M         8.8            UA          NaN
# 4            $315.54M         8.8             U          NaN
# ...               ...         ...           ...          ...
# 1746            *****         3.6           NaN          NaN
# 1747           $3.79M         3.5            UA          NaN
# 1748          $38.54M         3.5            PG          NaN
# 1749          $10.98M         3.5         PG-13          NaN
# 1750              NaN         NaN           NaN          NaN
#
# [1751 rows x 13 columns]

# %%
df2.columns
# Out:
# Index(['Movie Name', 'Stars Name1', 'Stars Name2', 'Stars Name3',
#        'Stars Name4', 'Votes', 'Genre1', 'Genre2', 'Genre3',
#        'Gross Collection', 'Popularity', 'Certification', 'Unnamed: 12'],
#       dtype='object')

# %%
# Merge the datasets on the Movie Name
df = pd.merge(df1, df2, on="Movie Name")

# %%
df
# Out:
#         SNO                                         Movie Name  \
# 0         1                                    The Dark Knight
# 1         2      The Lord of the Rings: The Return of the King
# 2         3                Spider-Man: Across the Spider-Verse
# 3         4                                          Inception
# 4         5  The Lord of the Rings: The Fellowship of the Ring
# ...     ...                                                ...
# 1804  1,745                        Mortal Kombat: Annihilation
# 1805  1,746                                               Krym
# 1806  1,747                                          Barb Wire
# 1807  1,748              Spy Kids 4: All the Time in the World
# 1808  1,749                                              D-War
#
#           Director Name1 Director Name2       Director Name3 Duration  \
# 0      Christopher Nolan            NaN                  NaN  152 min
# 1          Peter Jackson            NaN                  NaN  201 min
# 2     Joaquim Dos Santos    Kemp Powers   Justin K. Thompson  140 min
# 3      Christopher Nolan            NaN                  NaN  148 min
# 4          Peter Jackson            NaN                  NaN  178 min
# ...                  ...            ...                  ...      ...
# 1804    John R. Leonetti            NaN                  NaN   95 min
# 1805     Aleksey Pimanov            NaN                  NaN   99 min
# 1806         David Hogan            NaN                  NaN   98 min
# 1807    Robert Rodriguez            NaN                  NaN   89 min
# 1808      Hyung-rae Shim            NaN                  NaN  107 min
#
#           Year  Rating  Metascore        Stars Name1  ...         Stars Name3  \
# 0         2008     9.0       84.0     Christian Bale  ...       Aaron Eckhart
# 1         2003     9.0       94.0        Elijah Wood  ...        Ian McKellen
# 2         2023     8.9       86.0      Shameik Moore  ...   Brian Tyree Henry
# 3         2010     8.8       74.0  Leonardo DiCaprio  ...         Elliot Page
# 4         2001     8.8       92.0        Elijah Wood  ...       Orlando Bloom
# ...        ...     ...        ...                ...  ...                 ...
# 1804      1997     3.6       11.0         Robin Shou  ...         James Remar
# 1805  I) (2017     3.6        NaN      Roman Kurtsyn  ...       Pavel Kraynov
# 1806      1996     3.5       40.0    Pamela Anderson  ...   Adriana Alexander
# 1807      2011     3.5       37.0       Jessica Alba  ...         Joel McHale
# 1808      2007     3.5       33.0         Jason Behr  ...      Robert Forster
#
#              Stars Name4      Votes     Genre1               Genre2  \
# 0          Michael Caine  2,739,255     Action                Crime
# 1          Orlando Bloom  1,898,117     Action            Adventure
# 2      Luna Lauren Velez    182,431  Animation               Action
# 3           Ken Watanabe  2,430,810     Action            Adventure
# 4              Sean Bean  1,926,549     Action            Adventure
# ...                  ...        ...        ...                  ...
# 1804         Sandra Hess     56,693     Action            Adventure
# 1805      Pavel Trubiner     33,496     Action    Drama
# 1806      David Andriole     30,451     Action   Sci-Fi
# 1807     Rowan Blanchard     27,159     Action            Adventure
# 1808      Craig Robinson     25,068     Action                Drama
#
#                       Genre3 Gross Collection Popularity  Certification  \
# 0          Drama                     $534.86M        9.0             UA
# 1          Drama                     $377.85M        9.0              U
# 2      Adventure                        *****        8.9              U
# 3         Sci-Fi                     $292.58M        8.8             UA
# 4          Drama                     $315.54M        8.8              U
# ...                      ...              ...        ...            ...
# 1804     Fantasy                      $35.93M        3.6             UA
# 1805                     NaN            *****        3.6            NaN
# 1806                     NaN           $3.79M        3.5             UA
# 1807      Comedy                      $38.54M        3.5             PG
# 1808     Fantasy                      $10.98M        3.5          PG-13
#
#      Unnamed: 12
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 1804         NaN
# 1805         NaN
# 1806         NaN
# 1807         NaN
# 1808         NaN
#
# [1809 rows x 21 columns]

# %%
df.drop("Unnamed: 12", axis=1, inplace=True)

# %%
df
# Out:
#         SNO                                         Movie Name  \
# 0         1                                    The Dark Knight
# 1         2      The Lord of the Rings: The Return of the King
# 2         3                Spider-Man: Across the Spider-Verse
# 3         4                                          Inception
# 4         5  The Lord of the Rings: The Fellowship of the Ring
# ...     ...                                                ...
# 1804  1,745                        Mortal Kombat: Annihilation
# 1805  1,746                                               Krym
# 1806  1,747                                          Barb Wire
# 1807  1,748              Spy Kids 4: All the Time in the World
# 1808  1,749                                              D-War
#
#           Director Name1 Director Name2       Director Name3 Duration  \
# 0      Christopher Nolan            NaN                  NaN  152 min
# 1          Peter Jackson            NaN                  NaN  201 min
# 2     Joaquim Dos Santos    Kemp Powers   Justin K. Thompson  140 min
# 3      Christopher Nolan            NaN                  NaN  148 min
# 4          Peter Jackson            NaN                  NaN  178 min
# ...                  ...            ...                  ...      ...
# 1804    John R. Leonetti            NaN                  NaN   95 min
# 1805     Aleksey Pimanov            NaN                  NaN   99 min
# 1806         David Hogan            NaN                  NaN   98 min
# 1807    Robert Rodriguez            NaN                  NaN   89 min
# 1808      Hyung-rae Shim            NaN                  NaN  107 min
#
#           Year  Rating  Metascore        Stars Name1            Stars Name2  \
# 0         2008     9.0       84.0     Christian Bale           Heath Ledger
# 1         2003     9.0       94.0        Elijah Wood        Viggo Mortensen
# 2         2023     8.9       86.0      Shameik Moore       Hailee Steinfeld
# 3         2010     8.8       74.0  Leonardo DiCaprio   Joseph Gordon-Levitt
# 4         2001     8.8       92.0        Elijah Wood           Ian McKellen
# ...        ...     ...        ...                ...                    ...
# 1804      1997     3.6       11.0         Robin Shou            Talisa Soto
# 1805  I) (2017     3.6        NaN      Roman Kurtsyn        Evgeniya Lapova
# 1806      1996     3.5       40.0    Pamela Anderson          Amir AboulEla
# 1807      2011     3.5       37.0       Jessica Alba           Jeremy Piven
# 1808      2007     3.5       33.0         Jason Behr          Amanda Brooks
#
#              Stars Name3         Stars Name4      Votes     Genre1  \
# 0          Aaron Eckhart       Michael Caine  2,739,255     Action
# 1           Ian McKellen       Orlando Bloom  1,898,117     Action
# 2      Brian Tyree Henry   Luna Lauren Velez    182,431  Animation
# 3            Elliot Page        Ken Watanabe  2,430,810     Action
# 4          Orlando Bloom           Sean Bean  1,926,549     Action
# ...                  ...                 ...        ...        ...
# 1804         James Remar         Sandra Hess     56,693     Action
# 1805       Pavel Kraynov      Pavel Trubiner     33,496     Action
# 1806   Adriana Alexander      David Andriole     30,451     Action
# 1807         Joel McHale     Rowan Blanchard     27,159     Action
# 1808      Robert Forster      Craig Robinson     25,068     Action
#
#                    Genre2                  Genre3 Gross Collection  \
# 0                   Crime       Drama                     $534.86M
# 1               Adventure       Drama                     $377.85M
# 2                  Action   Adventure                        *****
# 3               Adventure      Sci-Fi                     $292.58M
# 4               Adventure       Drama                     $315.54M
# ...                   ...                     ...              ...
# 1804            Adventure     Fantasy                      $35.93M
# 1805    Drama                                 NaN            *****
# 1806   Sci-Fi                                 NaN           $3.79M
# 1807            Adventure      Comedy                      $38.54M
# 1808                Drama     Fantasy                      $10.98M
#
#       Popularity Certification
# 0            9.0            UA
# 1            9.0             U
# 2            8.9             U
# 3            8.8            UA
# 4            8.8             U
# ...          ...           ...
# 1804         3.6            UA
# 1805         3.6           NaN
# 1806         3.5            UA
# 1807         3.5            PG
# 1808         3.5         PG-13
#
# [1809 rows x 20 columns]

# %% [markdown]
# EDA process

# %%
df.head()
# Out:
#   SNO                                         Movie Name      Director Name1  \
# 0   1                                    The Dark Knight   Christopher Nolan
# 1   2      The Lord of the Rings: The Return of the King       Peter Jackson
# 2   3                Spider-Man: Across the Spider-Verse  Joaquim Dos Santos
# 3   4                                          Inception   Christopher Nolan
# 4   5  The Lord of the Rings: The Fellowship of the Ring       Peter Jackson
#
#   Director Name2       Director Name3 Duration  Year  Rating  Metascore  \
# 0            NaN                  NaN  152 min  2008     9.0       84.0
# 1            NaN                  NaN  201 min  2003     9.0       94.0
# 2    Kemp Powers   Justin K. Thompson  140 min  2023     8.9       86.0
# 3            NaN                  NaN  148 min  2010     8.8       74.0
# 4            NaN                  NaN  178 min  2001     8.8       92.0
#
#          Stars Name1            Stars Name2         Stars Name3  \
# 0     Christian Bale           Heath Ledger       Aaron Eckhart
# 1        Elijah Wood        Viggo Mortensen        Ian McKellen
# 2      Shameik Moore       Hailee Steinfeld   Brian Tyree Henry
# 3  Leonardo DiCaprio   Joseph Gordon-Levitt         Elliot Page
# 4        Elijah Wood           Ian McKellen       Orlando Bloom
#
#           Stars Name4      Votes     Genre1      Genre2  \
# 0       Michael Caine  2,739,255     Action       Crime
# 1       Orlando Bloom  1,898,117     Action   Adventure
# 2   Luna Lauren Velez    182,431  Animation      Action
# 3        Ken Watanabe  2,430,810     Action   Adventure
# 4           Sean Bean  1,926,549     Action   Adventure
#
#                    Genre3 Gross Collection  Popularity Certification
# 0       Drama                     $534.86M         9.0            UA
# 1       Drama                     $377.85M         9.0             U
# 2   Adventure                        *****         8.9             U
# 3      Sci-Fi                     $292.58M         8.8            UA
# 4       Drama                     $315.54M         8.8             U

# %%
df.tail()
# Out:
#         SNO                             Movie Name    Director Name1  \
# 1804  1,745            Mortal Kombat: Annihilation  John R. Leonetti
# 1805  1,746                                   Krym   Aleksey Pimanov
# 1806  1,747                              Barb Wire       David Hogan
# 1807  1,748  Spy Kids 4: All the Time in the World  Robert Rodriguez
# 1808  1,749                                  D-War    Hyung-rae Shim
#
#      Director Name2 Director Name3 Duration      Year  Rating  Metascore  \
# 1804            NaN            NaN   95 min      1997     3.6       11.0
# 1805            NaN            NaN   99 min  I) (2017     3.6        NaN
# 1806            NaN            NaN   98 min      1996     3.5       40.0
# 1807            NaN            NaN   89 min      2011     3.5       37.0
# 1808            NaN            NaN  107 min      2007     3.5       33.0
#
#           Stars Name1       Stars Name2         Stars Name3       Stars Name4  \
# 1804       Robin Shou       Talisa Soto         James Remar       Sandra Hess
# 1805    Roman Kurtsyn   Evgeniya Lapova       Pavel Kraynov    Pavel Trubiner
# 1806  Pamela Anderson     Amir AboulEla   Adriana Alexander    David Andriole
# 1807     Jessica Alba      Jeremy Piven         Joel McHale   Rowan Blanchard
# 1808       Jason Behr     Amanda Brooks      Robert Forster    Craig Robinson
#
#        Votes  Genre1               Genre2                Genre3  \
# 1804  56,693  Action            Adventure   Fantasy
# 1805  33,496  Action    Drama                               NaN
# 1806  30,451  Action   Sci-Fi                               NaN
# 1807  27,159  Action            Adventure    Comedy
# 1808  25,068  Action                Drama   Fantasy
#
#      Gross Collection  Popularity Certification
# 1804          $35.93M         3.6            UA
# 1805            *****         3.6           NaN
# 1806           $3.79M         3.5            UA
# 1807          $38.54M         3.5            PG
# 1808          $10.98M         3.5         PG-13

# %%
df.shape
# Out:
# (1809, 20)

# %%
df.columns
# Out:
# Index(['SNO', 'Movie Name', 'Director Name1', 'Director Name2',
#        'Director Name3', 'Duration', 'Year', 'Rating', 'Metascore',
#        'Stars Name1', 'Stars Name2', 'Stars Name3', 'Stars Name4', 'Votes',
#        'Genre1', 'Genre2', 'Genre3', 'Gross Collection', 'Popularity',
#        'Certification'],
#       dtype='object')

# %%
df.dtypes
# Out:
# SNO                  object
# Movie Name           object
# Director Name1       object
# Director Name2       object
# Director Name3       object
# Duration             object
# Year                 object
# Rating              float64
# Metascore           float64
# Stars Name1          object
# Stars Name2          object
# Stars Name3          object
# Stars Name4          object
# Votes                object
# Genre1               object
# Genre2               object
# Genre3               object
# Gross Collection     object
# Popularity          float64
# Certification        object
# dtype: object

# %%
df['Votes'] = df['Votes'].str.replace(',', '').astype(int)

# %%
df.dtypes
# Out:
# SNO                  object
# Movie Name           object
# Director Name1       object
# Director Name2       object
# Director Name3       object
# Duration             object
# Year                 object
# Rating              float64
# Metascore           float64
# Stars Name1          object
# Stars Name2          object
# Stars Name3          object
# Stars Name4          object
# Votes                 int32
# Genre1               object
# Genre2               object
# Genre3               object
# Gross Collection     object
# Popularity          float64
# Certification        object
# dtype: object

# %%
#checking the null values
df.isnull().sum()
# Out:
# SNO                    0
# Movie Name             0
# Director Name1         0
# Director Name2      1697
# Director Name3      1796
# Duration               0
# Year                   0
# Rating                 0
# Metascore            181
# Stars Name1            0
# Stars Name2            1
# Stars Name3            1
# Stars Name4            2
# Votes                  0
# Genre1                 0
# Genre2                 2
# Genre3               150
# Gross Collection       0
# Popularity             0
# Certification         73
# dtype: int64

# %%
# Replace null values in specified columns with appropriate values
columns_to_fill = ['Director Name2', 'Director Name3', 'Stars Name2', 'Stars Name3', 'Stars Name4',
                   'Genre2', 'Genre3', 'Certification']

# Replace null values with an empty string for string/object columns
df[columns_to_fill] = df[columns_to_fill].fillna('')

# Replace null values with 0 for numeric columns
df['Metascore'] = df['Metascore'].fillna(0)

# %%
#checking again for the null values
df.isnull().sum()
# Out:
# SNO                 0
# Movie Name          0
# Director Name1      0
# Director Name2      0
# Director Name3      0
# Duration            0
# Year                0
# Rating              0
# Metascore           0
# Stars Name1         0
# Stars Name2         0
# Stars Name3         0
# Stars Name4         0
# Votes               0
# Genre1              0
# Genre2              0
# Genre3              0
# Gross Collection    0
# Popularity          0
# Certification       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1809 entries, 0 to 1808
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SNO               1809 non-null   object
#  1   Movie Name        1809 non-null   object
#  2   Director Name1    1809 non-null   object
#  3   Director Name2    1809 non-null   object
#  4   Director Name3    1809 non-null   object
#  5   Duration          1809 non-null   object
#  6   Year              1809 non-null   object
#  7   Rating            1809 non-null   float64
#  8   Metascore         1809 non-null   float64
#  9   Stars Name1       1809 non-null   object
#  10  Stars Name2       1809 non-null   object
#  11  Stars Name3       1809 non-null   object
#  12  Stars Name4       1809 non-null   object
#  13  Votes             1809 non-null   int32
#  14  Genre1            1809 non-null   object
#  15  Genre2            1809 non-null   object
#  16  Genre3            1809 non-null   object
#  17  Gross Collection  1809 non-null   object
#  18  Popularity        1809 non-null   float64
#  19  Certification     1809 non-null   object
# dtypes: float64(3), int32(1), object(16)
# memory usage: 289.7+ KB

# %%
#check null value by using heatmap
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
#cheking no.of unique values in each column
df.nunique()
# Out:
# SNO                 1749
# Movie Name          1719
# Director Name1       927
# Director Name2        89
# Director Name3        14
# Duration             119
# Year                 112
# Rating                56
# Metascore             86
# Stars Name1          724
# Stars Name2         1166
# Stars Name3         1323
# Stars Name4         1441
# Votes               1742
# Genre1                 3
# Genre2                23
# Genre3                18
# Gross Collection    1353
# Popularity            56
# Certification         23
# dtype: int64

# %%
# checking the value counts of each column
for col in df.columns:
    print(df[col].value_counts())
    print('\n')
# Out:
# 550      2
# 592      2
# 1,740    2
# 87       2
# 386      2
#         ..
# 583      1
# 582      1
# 581      1
# 580      1
# 1,749    1
# Name: SNO, Length: 1749, dtype: int64
#
#
# Taxi                      4
# RoboCop                   4
# Mortal Kombat             4
# The Magnificent Seven     4
# Fantastic Four            4
#                          ..
# The Amazing Spider-Man    1
# Jurassic World            1
# National Treasure         1
# A Knight's Tale           1
# D-War                     1
# Name: Movie Name, Length: 1719, dtype: int64
#
#
# Michael Bay         15
# Robert Rodriguez    13
# Antoine Fuqua       13
# Roland Emmerich     13
# Steven Spielberg    13
#                     ..
# Rob Marshall         1
# Neil Burger          1
# John Dahl            1
# Adam McKay           1
# Hyung-rae Shim       1
# Name: Director Name1, Length: 927, dtype: int64
#
#
#                            1697
#  Lilly Wachowski              5
#  Joe Russo                    5
#  Brian Taylor                 4
#  Espen Sandberg               4
#                            ...
#  Heavenveer Singh Hayer       1
#  Jennifer Yuh Nelson          1
#  Sam J. Levine                1
#  Takeshi Nozue                1
#  Tyler Gillett                1
# Name: Director Name2, Length: 89, dtype: int64
#
#
#                            1796
#  Justin K. Thompson           1
#  Rodney Rothman               1
#  Gowtham Selvaraj             1
#  Frank Paur                   1
#  Tensai Okamura               1
#  Gerd Oswald                  1
#  Hideaki Anno                 1
#  Quentin Tarantino            1
#  Toshio Masuda                1
#  Paul Briggs                  1
#  Yoann-Karl Whissell          1
#  Bob Logan                    1
#  Musa Muhammed Olayinka       1
# Name: Director Name3, dtype: int64
#
#
# 107 min    49
# 100 min    46
# 109 min    43
# 110 min    42
# 105 min    41
#            ..
# 204 min     1
# 166 min     1
# 201 min     1
# 176 min     1
# 75 min      1
# Name: Duration, Length: 119, dtype: int64
#
#
# 2016         73
# 2011         66
# 2014         66
# 2018         64
# 2019         62
#              ..
# 1954          1
# 1924          1
# 1932          1
# 1948          1
# IV) (2020     1
# Name: Year, Length: 112, dtype: int64
#
#
# 6.1    95
# 6.2    92
# 6.6    87
# 6.3    83
# 6.7    82
# 6.5    81
# 6.4    81
# 7.0    71
# 6.9    67
# 7.1    63
# 7.3    59
# 7.2    59
# 6.0    58
# 5.7    55
# 5.9    55
# 6.8    54
# 5.8    54
# 5.6    54
# 7.6    49
# 7.5    40
# 5.5    38
# 7.8    37
# 7.7    36
# 5.4    33
# 7.4    32
# 5.3    28
# 5.2    27
# 8.0    26
# 8.1    24
# 7.9    23
# 8.2    21
# 5.1    19
# 4.7    12
# 8.3    11
# 5.0    11
# 4.5     9
# 8.4     9
# 4.9     9
# 4.8     9
# 4.2     5
# 4.4     5
# 8.6     5
# 4.3     5
# 4.6     5
# 3.8     4
# 4.0     3
# 3.9     3
# 3.6     3
# 3.5     3
# 8.7     3
# 8.8     3
# 4.1     2
# 8.5     2
# 3.7     2
# 9.0     2
# 8.9     1
# Name: Rating, dtype: int64
#
#
# 0.0     181
# 51.0     44
# 48.0     43
# 60.0     42
# 49.0     41
#        ...
# 20.0      1
# 15.0      1
# 88.0      1
# 92.0      1
# 11.0      1
# Name: Metascore, Length: 86, dtype: int64
#
#
# Sylvester Stallone       27
# Arnold Schwarzenegger    25
# Tom Cruise               22
# Bruce Willis             22
# Jason Statham            21
#                          ..
# Alden Ehrenreich          1
# Viola Davis               1
# Jorma Tommila             1
# Yu-Hang To                1
# Jason Behr                1
# Name: Stars Name1, Length: 724, dtype: int64
#
#
#  Samuel L. Jackson     14
#  Laurence Fishburne     9
#  Mark Wahlberg          8
#  Morgan Freeman         7
#  Paul Walker            7
#                        ..
#  Caleb Landry Jones     1
#  Edward Norton          1
#  Jason Isaacs           1
#  Jenny Agutter          1
#  Amanda Brooks          1
# Name: Stars Name2, Length: 1166, dtype: int64
#
#
#  Morgan Freeman       8
#  Samuel L. Jackson    7
#  Willem Dafoe         7
#  Sigourney Weaver     6
#  Ian McShane          6
#                      ..
#  Corey Burton         1
#  Gary Cole            1
#  Tory Kittles         1
#  Rebecca Robin        1
#  Joel McHale          1
# Name: Stars Name3, Length: 1323, dtype: int64
#
#
#  "Vincent DOnofrio"]    6
#  Jeffrey Wright         5
#  Famke Janssen          5
#  James Doohan           5
#  Don Cheadle            5
#                        ..
#  Emily Barclay          1
#  Hannah Al Rashid       1
#  Olivia Barash          1
#  Steve Burton           1
#  Craig Robinson         1
# Name: Stars Name4, Length: 1441, dtype: int64
#
#
# 43875     2
# 48591     2
# 46287     2
# 287891    2
# 44709     2
#          ..
# 448111    1
# 29162     1
# 201521    1
# 401871    1
# 25068     1
# Name: Votes, Length: 1742, dtype: int64
#
#
# Action                1736
# Animation               71
# Action                   2
# Name: Genre1, dtype: int64
#
#
#  Adventure                661
#  Crime                    354
#  Comedy                   213
#  Drama                    193
#  Action                    71
#  Thriller                  66
#  Horror                    46
#  Biography                 40
#  Sci-Fi                    35
#  Sci-Fi                    24
#  Mystery                   23
#  Comedy                    23
#  Drama                     19
#  Fantasy                   18
#  Adventure                  8
#  Thriller                   3
#  Crime                      3
#  Horror                     2
#  War                        2
#                             2
#  Fantasy                    1
#  Sport                      1
#  Family                     1
# Name: Genre2, dtype: int64
#
#
#  Drama                    339
#  Thriller                 321
#  Sci-Fi                   232
#  Crime                    175
#                           150
#  Comedy                   144
#  Fantasy                  134
#  Adventure                 61
#  Horror                    58
#  History                   41
#  Mystery                   41
#  Romance                   33
#  Family                    25
#  War                       20
#  Sport                     15
#  Biography                 11
#  Western                    8
#  Music                      1
# Name: Genre3, dtype: int64
#
#
# *****      288
# $0.03M       8
# $0.01M       7
# $0.04M       5
# $0.10M       5
#           ...
# $1.36M       1
# $1.98M       1
# $23.53M      1
# $27.44M      1
# $10.98M      1
# Name: Gross Collection, Length: 1353, dtype: int64
#
#
# 6.1    95
# 6.2    92
# 6.6    87
# 6.3    83
# 6.7    82
# 6.4    81
# 6.5    81
# 7.0    71
# 6.9    67
# 7.1    64
# 7.3    59
# 7.2    58
# 6.0    58
# 5.7    55
# 5.9    55
# 6.8    54
# 5.8    54
# 5.6    54
# 7.6    49
# 7.5    40
# 7.8    38
# 5.5    38
# 7.7    36
# 5.4    33
# 7.4    32
# 5.3    28
# 5.2    27
# 8.0    26
# 8.1    25
# 7.9    22
# 8.2    20
# 5.1    19
# 4.7    12
# 8.3    11
# 5.0    11
# 4.5     9
# 8.4     9
# 4.9     9
# 4.8     9
# 4.2     5
# 4.4     5
# 8.6     5
# 4.3     5
# 4.6     5
# 3.8     4
# 4.0     3
# 3.9     3
# 3.6     3
# 3.5     3
# 8.7     3
# 8.8     3
# 4.1     2
# 8.5     2
# 3.7     2
# 9.0     2
# 8.9     1
# Name: Popularity, dtype: int64
#
#
# UA           618
# A            413
# U            263
# R            215
# PG-13         78
#               73
# 18            37
# 16            25
# Not Rated     17
# PG            16
# 13            15
# UA 16+         9
# UA 13+         7
# 15+            7
# 7              4
# 12+            3
# (Banned)       2
# All            2
# UA 7+          1
# U/A            1
# 16+            1
# 12             1
# U/A 16+        1
# Name: Certification, dtype: int64

# %%
# Checking for duplicate values
print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
# List of numerical columns
numerical_cols = ['Rating', 'Metascore', 'Votes', 'Popularity']

# Create a new DataFrame containing only the numerical columns
num_df = df[numerical_cols]

# Print the new DataFrame
print(num_df)
# Out:
#       Rating  Metascore    Votes  Popularity
# 0        9.0       84.0  2739255         9.0
# 1        9.0       94.0  1898117         9.0
# 2        8.9       86.0   182431         8.9
# 3        8.8       74.0  2430810         8.8
# 4        8.8       92.0  1926549         8.8
# ...      ...        ...      ...         ...
# 1804     3.6       11.0    56693         3.6
# 1805     3.6        0.0    33496         3.6
# 1806     3.5       40.0    30451         3.5
# 1807     3.5       37.0    27159         3.5
# 1808     3.5       33.0    25068         3.5
#
# [1809 rows x 4 columns]

# %%
# List of categorical columns
categorical_cols = ['Movie Name', 'Director Name1', 'Director Name2', 'Director Name3', 
                    'Duration', 'Year', 'Stars Name1', 'Stars Name2', 'Stars Name3', 'Stars Name4', 
                    'Genre1', 'Genre2', 'Genre3', 'Gross Collection', 'Certification']

# Create a new DataFrame containing only the categorical columns
cat_df = df[categorical_cols]

# Print the new DataFrame
print(cat_df)
# Out:
#                                              Movie Name      Director Name1  \
# 0                                       The Dark Knight   Christopher Nolan
# 1         The Lord of the Rings: The Return of the King       Peter Jackson
# 2                   Spider-Man: Across the Spider-Verse  Joaquim Dos Santos
# 3                                             Inception   Christopher Nolan
# 4     The Lord of the Rings: The Fellowship of the Ring       Peter Jackson
# ...                                                 ...                 ...
# 1804                        Mortal Kombat: Annihilation    John R. Leonetti
# 1805                                               Krym     Aleksey Pimanov
# 1806                                          Barb Wire         David Hogan
# 1807              Spy Kids 4: All the Time in the World    Robert Rodriguez
# 1808                                              D-War      Hyung-rae Shim
#
#      Director Name2       Director Name3 Duration      Year  \
# 0                                         152 min      2008
# 1                                         201 min      2003
# 2       Kemp Powers   Justin K. Thompson  140 min      2023
# 3                                         148 min      2010
# 4                                         178 min      2001
# ...             ...                  ...      ...       ...
# 1804                                       95 min      1997
# 1805                                       99 min  I) (2017
# 1806                                       98 min      1996
# 1807                                       89 min      2011
# 1808                                      107 min      2007
#
#             Stars Name1            Stars Name2         Stars Name3  \
# 0        Christian Bale           Heath Ledger       Aaron Eckhart
# 1           Elijah Wood        Viggo Mortensen        Ian McKellen
# 2         Shameik Moore       Hailee Steinfeld   Brian Tyree Henry
# 3     Leonardo DiCaprio   Joseph Gordon-Levitt         Elliot Page
# 4           Elijah Wood           Ian McKellen       Orlando Bloom
# ...                 ...                    ...                 ...
# 1804         Robin Shou            Talisa Soto         James Remar
# 1805      Roman Kurtsyn        Evgeniya Lapova       Pavel Kraynov
# 1806    Pamela Anderson          Amir AboulEla   Adriana Alexander
# 1807       Jessica Alba           Jeremy Piven         Joel McHale
# 1808         Jason Behr          Amanda Brooks      Robert Forster
#
#              Stars Name4     Genre1               Genre2  \
# 0          Michael Caine     Action                Crime
# 1          Orlando Bloom     Action            Adventure
# 2      Luna Lauren Velez  Animation               Action
# 3           Ken Watanabe     Action            Adventure
# 4              Sean Bean     Action            Adventure
# ...                  ...        ...                  ...
# 1804         Sandra Hess     Action            Adventure
# 1805      Pavel Trubiner     Action    Drama
# 1806      David Andriole     Action   Sci-Fi
# 1807     Rowan Blanchard     Action            Adventure
# 1808      Craig Robinson     Action                Drama
#
#                       Genre3 Gross Collection Certification
# 0          Drama                     $534.86M            UA
# 1          Drama                     $377.85M             U
# 2      Adventure                        *****             U
# 3         Sci-Fi                     $292.58M            UA
# 4          Drama                     $315.54M             U
# ...                      ...              ...           ...
# 1804     Fantasy                      $35.93M            UA
# 1805                                    *****
# 1806                                   $3.79M            UA
# 1807      Comedy                      $38.54M            PG
# 1808     Fantasy                      $10.98M         PG-13
#
# [1809 rows x 15 columns]

# %%
description = num_df.describe()
description
# Out:
#             Rating    Metascore         Votes   Popularity
# count  1809.000000  1809.000000  1.809000e+03  1809.000000
# mean      6.514760    48.087341  1.820908e+05     6.514594
# std       0.909036    22.138495  2.370118e+05     0.908817
# min       3.500000     0.000000  2.500900e+04     3.500000
# 25%       5.900000    37.000000  4.767000e+04     5.900000
# 50%       6.500000    51.000000  9.734200e+04     6.500000
# 75%       7.100000    64.000000  2.152680e+05     7.100000
# max       9.000000    98.000000  2.739255e+06     9.000000

# %% [markdown]
# Univarient analysis

# %%
# for target columns ('Votes','Gross Collection')
# Votes

plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='Votes', bins=20)
plt.title('Votes Distribution')
plt.xlabel('Votes')
plt.ylabel('Frequency')
plt.show()

# %%
#Gross Collection
plt.figure(figsize=(8, 6))
plt.hist(df['Gross Collection'], bins=10, edgecolor='black')
plt.title('Gross Collection Distribution')
plt.xlabel('Gross Collection')
plt.ylabel('Frequency')
plt.show()

# %%
# for numerical columns
plt.figure(figsize=(8, 4))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(2, 2, i)
    sns.histplot(df[col], kde=True)
    plt.xlabel(col)
    plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# for categorical columns
plt.figure(figsize=(12, 18))
for i, col in enumerate(categorical_cols, 1):
    plt.subplot(8, 2, i)
    sns.countplot(x=col, data=df)
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Bivariate Analysis

# %%
# Relationship between Votes and numerical columns
N_col = ['Rating', 'Metascore','Popularity']
plt.figure(figsize=(8, 8))
for i, col in enumerate(N_col, 1):
    plt.subplot(2, 2, i)
    sns.boxplot(x='Votes', y=col, data=df)
    plt.xlabel('Votes')
    plt.ylabel(col)
plt.tight_layout()
plt.show()

# %%
# Relationship between Gross Collection and numerical columns
plt.figure(figsize=(10, 12))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(3, 2, i)
    sns.boxplot(x='Gross Collection', y=col, data=df)
    plt.xlabel('Gross Collection')
    plt.ylabel(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# Multivariate Analysis

# %%
# Relationship between Votes, Popularity, and Metascore
plt.figure(figsize=(6, 4))
sns.scatterplot(x='Metascore', y='Popularity', hue='Votes', data=df)
plt.xlabel('Metascore')
plt.ylabel('Popularity')
plt.title('Votes vs Metascore vs Popularity')
plt.show()

# %%
#check for outliers
df_outliers = df[numerical_cols]
df_outliers.plot(kind='box', subplots=True, layout=(7, 4), fontsize=10, figsize=(12, 18))
plt.show()

# %%
#remove outliers with z-score method
from scipy.stats import zscore
out_df = df[numerical_cols]
z = np.abs(zscore(out_df))
z
# Out:
#         Rating  Metascore      Votes  Popularity
# 0     2.734684   1.622630  10.792169    2.735527
# 1     2.734684   2.074457   7.242259    2.735527
# 2     2.624647   1.712996   0.001436    2.625463
# 3     2.514610   1.170803   9.490418    2.515400
# 4     2.514610   1.984092   7.362252    2.515400
# ...        ...        ...        ...         ...
# 1804  3.207314   1.675705   0.529224    3.207906
# 1805  3.207314   2.172715   0.627124    3.207906
# 1806  3.317351   0.365408   0.639975    3.317970
# 1807  3.317351   0.500956   0.653869    3.317970
# 1808  3.317351   0.681686   0.662693    3.317970
#
# [1809 rows x 4 columns]

# %%
#threshold value = 3
z_score_threshold = 3

# %%
outliers = np.any(z > z_score_threshold, axis=1)

# %%
df_out = df[~outliers]

# %%
df_out.shape
# Out:
# (1770, 20)

# %%
#shape of old and new data frame
print("old df_",df.shape[0])
print("New df_",df_out.shape[0])
# Out:
# old df_ 1809
# New df_ 1770

# %%
#view data loss by persentage 
print("data loss percentage_",((df.shape[0]-df_out.shape[0])/df.shape[0])*100)
# Out:
# data loss percentage_ 2.155887230514096

# %%
df=df_out

# %%
# check skewness 
df.skew()
# Out:
# Rating       -0.172115
# Metascore    -0.655872
# Votes         1.963847
# Popularity   -0.184008
# dtype: float64

# %%
#lets check how the data hase been distributed in numerical columns
plt.figure(figsize=(10, 18))  
plotnumber = 1
for col in numerical_cols:
    if plotnumber <=7:
        plt.subplot(7, 1, plotnumber)
        sns.distplot(df[col], color="m")
        plt.xlabel(col, fontsize=12)
        plt.xticks(rotation=0, fontsize=10)
        plt.yticks(rotation=0, fontsize=10)
        plotnumber += 1

plt.tight_layout()
plt.show()

# %%
# apply cube root transformation to reduce skewness
for col in numerical_cols:
    if df[col].skew() > 0.5:
        df[col] = np.cbrt(df[col])

# %%
#checking skewness again
df.skew()
# Out:
# Rating       -0.172115
# Metascore    -0.655872
# Votes         0.849034
# Popularity   -0.184008
# dtype: float64

# %%
#lets check again how the data hase been distributed in numerical columns
plt.figure(figsize=(10, 18))  
plotnumber = 1
for col in numerical_cols:
    if plotnumber <= 7:
        plt.subplot(7, 1, plotnumber)
        sns.distplot(df[col], color="m")
        plt.xlabel(col, fontsize=12)
        plt.xticks(rotation=0, fontsize=10)
        plt.yticks(rotation=0, fontsize=10)
        plotnumber += 1

plt.tight_layout()
plt.show()

# %%
# Encode categorical columns using Ordinal Encoder
from sklearn.preprocessing import OrdinalEncoder

OE = OrdinalEncoder()
for i in df.columns:
    if df[i].dtype == 'object':
        df[i] = OE.fit_transform(df[i].values.reshape(-1,1))


df
# Out:
#          SNO  Movie Name  Director Name1  Director Name2  Director Name3  \
# 2      950.0      1138.0           399.0            49.0             6.0
# 8     1601.0      1119.0           838.0             0.0             0.0
# 11     760.0      1079.0            15.0             0.0             0.0
# 12     771.0      1057.0           560.0             0.0             0.0
# 13     781.0      1093.0           321.0             0.0             0.0
# ...      ...         ...             ...             ...             ...
# 1796   736.0       403.0           825.0             0.0             0.0
# 1797   737.0      1131.0           365.0             0.0             0.0
# 1798   738.0      1237.0           749.0             0.0             0.0
# 1799   739.0       142.0           405.0             0.0             0.0
# 1800   741.0       590.0           890.0             0.0             0.0
#
#       Duration  Year  Rating  Metascore  Stars Name1  Stars Name2  \
# 2         40.0  73.0     8.9       86.0        601.0        402.0
# 8         53.0  70.0     8.7        0.0        629.0        862.0
# 11        87.0   7.0     8.6       98.0        664.0       1045.0
# 12        33.0  12.0     8.6       85.0        637.0         27.0
# 13        62.0  72.0     8.6        0.0        169.0        801.0
# ...        ...   ...     ...        ...          ...          ...
# 1796     113.0  68.0     3.9        0.0        630.0        253.0
# 1797      21.0  47.0     3.9       23.0        579.0        480.0
# 1798     112.0  52.0     3.9       12.0        176.0        487.0
# 1799      25.0  47.0     3.8       28.0         53.0        379.0
# 1800      27.0  57.0     3.8       15.0        285.0        943.0
#
#       Stars Name3  Stars Name4      Votes  Genre1  Genre2  Genre3  \
# 2           162.0        816.0  56.715210     2.0     1.0     1.0
# 8           103.0       1348.0  49.323008     0.0    10.0     0.0
# 11          660.0       1407.0  70.792491     0.0    10.0     0.0
# 12         1138.0       1299.0  39.585086     0.0     9.0    11.0
# 13         1002.0       1269.0  39.443759     0.0     9.0    11.0
# ...           ...          ...        ...     ...     ...     ...
# 1796       1283.0        587.0  32.290646     0.0     7.0    11.0
# 1797       1272.0       1292.0  43.808569     0.0     2.0     4.0
# 1798       1000.0       1155.0  29.827529     0.0     5.0    13.0
# 1799          3.0       1347.0  63.925450     0.0    18.0     0.0
# 1800       1005.0        769.0  36.906998     0.0     2.0     7.0
#
#       Gross Collection  Popularity  Certification
# 2               1316.0         8.9           16.0
# 8               1316.0         8.7           16.0
# 11                20.0         8.6           16.0
# 12              1316.0         8.6            0.0
# 13              1316.0         8.6           16.0
# ...                ...         ...            ...
# 1796            1316.0         3.9           10.0
# 1797             954.0         3.9           19.0
# 1798             836.0         3.9           14.0
# 1799             126.0         3.8           16.0
# 1800             838.0         3.8           19.0
#
# [1770 rows x 20 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1770 entries, 2 to 1800
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SNO               1770 non-null   float64
#  1   Movie Name        1770 non-null   float64
#  2   Director Name1    1770 non-null   float64
#  3   Director Name2    1770 non-null   float64
#  4   Director Name3    1770 non-null   float64
#  5   Duration          1770 non-null   float64
#  6   Year              1770 non-null   float64
#  7   Rating            1770 non-null   float64
#  8   Metascore         1770 non-null   float64
#  9   Stars Name1       1770 non-null   float64
#  10  Stars Name2       1770 non-null   float64
#  11  Stars Name3       1770 non-null   float64
#  12  Stars Name4       1770 non-null   float64
#  13  Votes             1770 non-null   float64
#  14  Genre1            1770 non-null   float64
#  15  Genre2            1770 non-null   float64
#  16  Genre3            1770 non-null   float64
#  17  Gross Collection  1770 non-null   float64
#  18  Popularity        1770 non-null   float64
#  19  Certification     1770 non-null   float64
# dtypes: float64(20)
# memory usage: 290.4 KB

# %%
df.describe()
# Out:
#                SNO   Movie Name  Director Name1  Director Name2  \
# count  1770.000000  1770.000000     1770.000000     1770.000000
# mean    854.759887   843.289831      482.134463        2.645198
# std     494.069602   486.266858      261.209430       11.949895
# min       0.000000     0.000000        0.000000        0.000000
# 25%     429.250000   424.250000      264.250000        0.000000
# 50%     853.500000   845.500000      490.500000        0.000000
# 75%    1281.750000  1265.750000      711.750000        0.000000
# max    1711.000000  1681.000000      919.000000       88.000000
#
#        Director Name3     Duration         Year       Rating    Metascore  \
# count     1770.000000  1770.000000  1770.000000  1770.000000  1770.000000
# mean         0.051412    42.677966    58.057062     6.498757    47.750282
# std          0.678475    40.671918    15.728822     0.861938    21.965357
# min          0.000000     0.000000     0.000000     3.800000     0.000000
# 25%          0.000000    11.000000    50.000000     5.900000    37.000000
# 50%          0.000000    25.000000    60.000000     6.500000    50.000000
# 75%          0.000000    77.000000    67.000000     7.100000    63.000000
# max         13.000000   116.000000   111.000000     8.900000    98.000000
#
#        Stars Name1  Stars Name2  Stars Name3  Stars Name4        Votes  \
# count  1770.000000  1770.000000  1770.000000  1770.000000  1770.000000
# mean    356.464972   583.266102   646.924859   704.109040    49.405923
# std     206.842059   327.248468   377.532966   415.434298    15.947452
# min       0.000000     0.000000     0.000000     0.000000    29.243686
# 25%     171.000000   303.000000   318.250000   342.250000    36.224675
# 50%     353.500000   585.500000   637.500000   692.500000    45.740819
# 75%     547.000000   867.750000   974.750000  1069.750000    58.985226
# max     714.000000  1155.000000  1307.000000  1420.000000    96.242299
#
#             Genre1       Genre2       Genre3  Gross Collection   Popularity  \
# count  1770.000000  1770.000000  1770.000000       1770.000000  1770.000000
# mean      0.081356     6.099435     7.881356        740.906780     6.496215
# std       0.393765     4.977422     5.129586        437.264915     0.863343
# min       0.000000     0.000000     0.000000          0.000000     3.800000
# 25%       0.000000     2.000000     4.000000        357.000000     5.900000
# 50%       0.000000     5.000000     6.500000        756.500000     6.500000
# 75%       0.000000     7.000000    13.000000       1166.750000     7.100000
# max       2.000000    22.000000    17.000000       1316.000000     8.900000
#
#        Certification
# count    1770.000000
# mean       14.227119
# std         4.961508
# min         0.000000
# 25%        10.000000
# 50%        15.000000
# 75%        19.000000
# max        22.000000

# %%
# check correlation 
cor = df.corr()
cor
# Out:
#                        SNO  Movie Name  Director Name1  Director Name2  \
# SNO               1.000000    0.029003       -0.010639        0.059351
# Movie Name        0.029003    1.000000       -0.004609       -0.015059
# Director Name1   -0.010639   -0.004609        1.000000       -0.063823
# Director Name2    0.059351   -0.015059       -0.063823        1.000000
# Director Name3    0.012555    0.035388       -0.002176        0.214348
# Duration         -0.095766   -0.027535       -0.038703        0.042318
# Year             -0.075989   -0.030396       -0.064720        0.009362
# Rating            0.425644    0.006790        0.000319        0.071403
# Metascore         0.205436    0.022853       -0.041959        0.034941
# Stars Name1       0.002413   -0.000588        0.009198       -0.047835
# Stars Name2      -0.017619    0.005161        0.028432        0.017420
# Stars Name3      -0.005281    0.020374        0.002201       -0.004942
# Stars Name4       0.052453    0.010558        0.037191        0.032969
# Votes             0.172178    0.017499       -0.015675       -0.030117
# Genre1            0.040295   -0.032162       -0.027570        0.328221
# Genre2           -0.004304   -0.002428       -0.008952       -0.075932
# Genre3            0.011636    0.051886        0.025509       -0.084930
# Gross Collection -0.045964    0.024185       -0.012323       -0.009646
# Popularity        0.400951    0.004466       -0.000995        0.071939
# Certification    -0.042942   -0.033337        0.017996       -0.012446
#
#                   Director Name3  Duration      Year    Rating  Metascore  \
# SNO                     0.012555 -0.095766 -0.075989  0.425644   0.205436
# Movie Name              0.035388 -0.027535 -0.030396  0.006790   0.022853
# Director Name1         -0.002176 -0.038703 -0.064720  0.000319  -0.041959
# Director Name2          0.214348  0.042318  0.009362  0.071403   0.034941
# Director Name3          1.000000  0.021803 -0.012035  0.088556   0.040538
# Duration                0.021803  1.000000 -0.005143 -0.124935  -0.154792
# Year                   -0.012035 -0.005143  1.000000 -0.144052  -0.155501
# Rating                  0.088556 -0.124935 -0.144052  1.000000   0.374639
# Metascore               0.040538 -0.154792 -0.155501  0.374639   1.000000
# Stars Name1             0.022351  0.049441 -0.016418  0.040213  -0.034899
# Stars Name2             0.021663 -0.020849  0.004361  0.018541  -0.039581
# Stars Name3            -0.007341  0.024503 -0.029022 -0.015969  -0.053963
# Stars Name4             0.002786  0.034612 -0.010744  0.030632  -0.019495
# Votes                  -0.021861 -0.182575  0.073001  0.353953   0.401352
# Genre1                  0.166305  0.093586  0.021520  0.145201   0.102609
# Genre2                 -0.030641  0.034527  0.079260 -0.009959  -0.099423
# Genre3                 -0.032843 -0.049052 -0.082640 -0.011553   0.023327
# Gross Collection       -0.030983 -0.031568  0.095939  0.010623  -0.163959
# Popularity              0.088635 -0.128593 -0.119463  0.962316   0.356555
# Certification          -0.039911 -0.022692  0.069758 -0.059430   0.015262
#
#                   Stars Name1  Stars Name2  Stars Name3  Stars Name4  \
# SNO                  0.002413    -0.017619    -0.005281     0.052453
# Movie Name          -0.000588     0.005161     0.020374     0.010558
# Director Name1       0.009198     0.028432     0.002201     0.037191
# Director Name2      -0.047835     0.017420    -0.004942     0.032969
# Director Name3       0.022351     0.021663    -0.007341     0.002786
# Duration             0.049441    -0.020849     0.024503     0.034612
# Year                -0.016418     0.004361    -0.029022    -0.010744
# Rating               0.040213     0.018541    -0.015969     0.030632
# Metascore           -0.034899    -0.039581    -0.053963    -0.019495
# Stars Name1          1.000000     0.004206     0.029779     0.012289
# Stars Name2          0.004206     1.000000     0.034002     0.048530
# Stars Name3          0.029779     0.034002     1.000000     0.047217
# Stars Name4          0.012289     0.048530     0.047217     1.000000
# Votes               -0.018943    -0.011381    -0.040879    -0.026265
# Genre1               0.002978    -0.047902     0.002448     0.039296
# Genre2               0.012620    -0.010421     0.042343    -0.012313
# Genre3               0.029311    -0.018685     0.014632    -0.003911
# Gross Collection    -0.004782    -0.022899     0.001139     0.021918
# Popularity           0.034070     0.008352    -0.024161     0.026568
# Certification       -0.027446    -0.005147     0.010828     0.064039
#
#                      Votes    Genre1    Genre2    Genre3  Gross Collection  \
# SNO               0.172178  0.040295 -0.004304  0.011636         -0.045964
# Movie Name        0.017499 -0.032162 -0.002428  0.051886          0.024185
# Director Name1   -0.015675 -0.027570 -0.008952  0.025509         -0.012323
# Director Name2   -0.030117  0.328221 -0.075932 -0.084930         -0.009646
# Director Name3   -0.021861  0.166305 -0.030641 -0.032843         -0.030983
# Duration         -0.182575  0.093586  0.034527 -0.049052         -0.031568
# Year              0.073001  0.021520  0.079260 -0.082640          0.095939
# Rating            0.353953  0.145201 -0.009959 -0.011553          0.010623
# Metascore         0.401352  0.102609 -0.099423  0.023327         -0.163959
# Stars Name1      -0.018943  0.002978  0.012620  0.029311         -0.004782
# Stars Name2      -0.011381 -0.047902 -0.010421 -0.018685         -0.022899
# Stars Name3      -0.040879  0.002448  0.042343  0.014632          0.001139
# Stars Name4      -0.026265  0.039296 -0.012313 -0.003911          0.021918
# Votes             1.000000 -0.025070 -0.070912  0.122520         -0.121185
# Genre1           -0.025070  1.000000 -0.212372 -0.254936         -0.022560
# Genre2           -0.070912 -0.212372  1.000000  0.051120          0.029568
# Genre3            0.122520 -0.254936  0.051120  1.000000         -0.031567
# Gross Collection -0.121185 -0.022560  0.029568 -0.031567          1.000000
# Popularity        0.362464  0.145574 -0.009792 -0.007390          0.006861
# Certification     0.159037  0.055930 -0.110011 -0.001095         -0.118198
#
#                   Popularity  Certification
# SNO                 0.400951      -0.042942
# Movie Name          0.004466      -0.033337
# Director Name1     -0.000995       0.017996
# Director Name2      0.071939      -0.012446
# Director Name3      0.088635      -0.039911
# Duration           -0.128593      -0.022692
# Year               -0.119463       0.069758
# Rating              0.962316      -0.059430
# Metascore           0.356555       0.015262
# Stars Name1         0.034070      -0.027446
# Stars Name2         0.008352      -0.005147
# Stars Name3        -0.024161       0.010828
# Stars Name4         0.026568       0.064039
# Votes               0.362464       0.159037
# Genre1              0.145574       0.055930
# Genre2             -0.009792      -0.110011
# Genre3             -0.007390      -0.001095
# Gross Collection    0.006861      -0.118198
# Popularity          1.000000      -0.065467
# Certification      -0.065467       1.000000

# %%
# Visualizing the correlation by plotting a heatmap
plt.figure(figsize=(20, 15))
sns.heatmap(df.corr(), linewidths=0.1, fmt=".1g", linecolor="black", annot=True, cmap="Blues")
plt.yticks(rotation=0)
plt.show()

# %%
#visulaizing the correlation  between label and features using bar plot 
#Votes
plt.figure(figsize=(22, 7))
df.corr()['Votes'].sort_values(ascending=False).drop(['Votes']).plot(kind='bar', color='magenta')
plt.xlabel('Features', fontsize=15)
plt.ylabel('Target', fontsize=15)
plt.title('Correlation between Features and Label', fontsize=20)
plt.show()

# %%
#visulaizing the correlation  between label and features using bar plot 
#Gross Collection
plt.figure(figsize=(22, 7))
df.corr()['Gross Collection'].sort_values(ascending=False).drop(['Gross Collection']).plot(kind='bar', color='magenta')
plt.xlabel('Features', fontsize=15)
plt.ylabel('Target', fontsize=15)
plt.title('Correlation between Features and Label', fontsize=20)
plt.show()

# %% [markdown]
# FIRST WE DO REGRESSION TASK (Votes)

# %%
#Separating features and label
X_reg = df.drop("Votes",axis=1)
y_reg= df["Votes"]

# %%
#Feature Scalling using standard scalarization
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_reg = pd.DataFrame(scaler.fit_transform(X_reg), columns=X_reg.columns)
X_reg
# Out:
#            SNO  Movie Name  Director Name1  Director Name2  Director Name3  \
# 0     0.192821    0.606238       -0.318357        3.880193        8.770060
# 1     1.510822    0.567154        1.362761       -0.221420       -0.075798
# 2    -0.191849    0.484871       -1.788858       -0.221420       -0.075798
# 3    -0.169578    0.439616        0.298180       -0.221420       -0.075798
# 4    -0.149333    0.513670       -0.617053       -0.221420       -0.075798
# ...        ...         ...             ...             ...             ...
# 1765 -0.240439   -0.905705        1.312979       -0.221420       -0.075798
# 1766 -0.238414    0.591839       -0.448558       -0.221420       -0.075798
# 1767 -0.236390    0.809887        1.021942       -0.221420       -0.075798
# 1768 -0.234365   -1.442599       -0.295381       -0.221420       -0.075798
# 1769 -0.230316   -0.521034        1.561892       -0.221420       -0.075798
#
#       Duration      Year    Rating  Metascore  Stars Name1  Stars Name2  \
# 0    -0.065862  0.950304  2.786651   1.741858     1.182565    -0.554066
# 1     0.253859  0.759517  2.554550  -2.174505     1.317972     0.851991
# 2     1.090053 -3.247000  2.438500   2.288327     1.487231     1.411357
# 3    -0.238019 -2.929023  2.438500   1.696319     1.356660    -1.700308
# 4     0.475205  0.886708  2.438500  -2.174505    -0.906576     0.665535
# ...        ...       ...       ...        ...          ...          ...
# 1765  1.729496  0.632326 -3.015867  -2.174505     1.322808    -1.009506
# 1766 -0.533147 -0.703180 -3.015867  -1.127106     1.076173    -0.315648
# 1767  1.704902 -0.385202 -3.015867  -1.628036    -0.872724    -0.294251
# 1768 -0.434771 -0.703180 -3.131917  -0.899410    -1.467548    -0.624369
# 1769 -0.385583 -0.067224 -3.131917  -1.491418    -0.345603     1.099579
#
#       Stars Name3  Stars Name4    Genre1    Genre2    Genre3  \
# 0       -1.284820     0.269411  4.873940 -1.024803 -1.341882
# 1       -1.441142     1.550361 -0.206669  0.783873 -1.536885
# 2        0.034643     1.692421 -0.206669  0.783873 -1.536885
# 3        1.301115     1.432378 -0.206669  0.582909  0.608144
# 4        0.940780     1.360144 -0.206669  0.582909  0.608144
# ...           ...          ...       ...       ...       ...
# 1765     1.685296    -0.281975 -0.206669  0.180981  0.608144
# 1766     1.656152     1.415524 -0.206669 -0.823839 -0.756874
# 1767     0.935481     1.085655 -0.206669 -0.220947  0.998149
# 1768    -1.706094     1.547953 -0.206669  2.391585 -1.536885
# 1769     0.948729     0.156244 -0.206669 -0.823839 -0.171867
#
#       Gross Collection  Popularity  Certification
# 0             1.315577    2.785062       0.357428
# 1             1.315577    2.553339       0.357428
# 2            -1.649139    2.437478       0.357428
# 3             1.315577    2.437478      -2.868309
# 4             1.315577    2.437478       0.357428
# ...                ...         ...            ...
# 1765          1.315577   -3.008014      -0.852223
# 1766          0.487470   -3.008014       0.962254
# 1767          0.217534   -3.008014      -0.045789
# 1768         -1.406654   -3.123875       0.357428
# 1769          0.222109   -3.123875       0.962254
#
# [1770 rows x 19 columns]

# %%
#checking again variance inflation factor (vif)
from statsmodels.stats.outliers_influence import variance_inflation_factor

Vif = pd.DataFrame()
Vif['VIF Values'] = [variance_inflation_factor(X_reg.values, i) for i in range(len(X_reg.columns))]
Vif['Features'] = X_reg.columns
Vif
# Out:
#     VIF Values          Features
# 0     1.242680               SNO
# 1     1.009718        Movie Name
# 2     1.016569    Director Name1
# 3     1.168596    Director Name2
# 4     1.071747    Director Name3
# 5     1.064879          Duration
# 6     1.077746              Year
# 7    14.320110            Rating
# 8     1.266029         Metascore
# 9     1.013886       Stars Name1
# 10    1.016835       Stars Name2
# 11    1.012098       Stars Name3
# 12    1.019035       Stars Name4
# 13    1.304091            Genre1
# 14    1.081151            Genre2
# 15    1.085173            Genre3
# 16    1.068188  Gross Collection
# 17   13.705016        Popularity
# 18    1.052797     Certification

# %%
y_reg.value_counts()
# Out:
# 32.844694    2
# 56.720909    2
# 39.227684    2
# 60.412984    2
# 42.924150    2
#             ..
# 49.743352    1
# 62.098439    1
# 42.492686    1
# 51.360890    1
# 36.906998    1
# Name: Votes, Length: 1704, dtype: int64

# %% [markdown]
# modelling for regression

# %%
#import liabraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
#finding the best random state

MaxAccu = 0
MaxRs = 0

for i in range(1, 200):
    X_reg_train, X_reg_test, y_reg_train, y_reg_test = train_test_split(X_reg, y_reg, test_size=0.3, random_state=i)
    lr = LinearRegression()
    lr.fit(X_reg_train, y_reg_train)
    pred = lr.predict(X_reg_test)
    acc = r2_score(y_reg_test, pred)
    if acc > MaxAccu:
        MaxAccu = acc
        MaxRs = i

print("Maximum R2 score is", MaxAccu, "on Random State", MaxRs)
# Out:
# Maximum R2 score is 0.3650446665594448 on Random State 105

# %%
X_reg_train, X_reg_test, y_reg_train,y_reg_test = train_test_split(X_reg, y_reg, test_size=0.3, random_state=105)

# %%
#modelling
#import liabraries
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

# %%
lr.fit(X_reg_train,y_reg_train)
pred_lr = lr.predict(X_reg_test)
pred_train = lr.predict(X_reg_train)

print("R2_score:",r2_score(y_reg_test,pred_lr))
print("R2_score on training Data:",r2_score(y_reg_train,pred_train)*100)
print ("MeanAbsoluteError:",mean_absolute_error(y_reg_test,pred_lr))
print ("MeanSquaredError:",mean_squared_error(y_reg_test,pred_lr))
print ("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_reg_test,pred_lr)))
# Out:
# R2_score: 0.3650446665594448
# R2_score on training Data: 27.864313066520687
# MeanAbsoluteError: 10.136870814171663
# MeanSquaredError: 154.9727694490913
# Root Mean Squared Error: 12.448805944711777

# %%
Rd = Ridge()
Rd.fit(X_reg_train, y_reg_train)
pred_Rd = Rd.predict(X_reg_test)
pred_train = Rd.predict(X_reg_train)

print("R2_score:", r2_score(y_reg_test, pred_Rd))
print("R2_score on training Data:", r2_score(y_reg_train, pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_reg_test, pred_Rd))
print("Mean Squared Error:", mean_squared_error(y_reg_test, pred_Rd))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg_test, pred_Rd)))
# Out:
# R2_score: 0.3650092949910776
# R2_score on training Data: 27.864258088817273
# Mean Absolute Error: 10.137508119469443
# Mean Squared Error: 154.98140254439883
# Root Mean Squared Error: 12.449152683793336

# %%
Dtr = DecisionTreeRegressor()
Dtr.fit(X_reg_train, y_reg_train)
pred_Dtr = Dtr.predict(X_reg_test)
pred_train = Dtr.predict(X_reg_train)

print("R2_score:", r2_score(y_reg_test, pred_Dtr))
print("R2_score on training Data:", r2_score(y_reg_train, pred_train))
print("Mean Absolute Error:", mean_absolute_error(y_reg_test, pred_Dtr))
print("Mean Squared Error:", mean_squared_error(y_reg_test, pred_Dtr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg_test, pred_Dtr)))
# Out:
# R2_score: 0.1322134766357974
# R2_score on training Data: 1.0
# Mean Absolute Error: 10.890417086512228
# Mean Squared Error: 211.79959240225742
# Root Mean Squared Error: 14.553336126203416

# %%
Rfr = RandomForestRegressor()
Rfr.fit(X_reg_train, y_reg_train)
pred_Rfr = Rfr.predict(X_reg_test)
pred_train = Rfr.predict(X_reg_train)

print("R2_score:", r2_score(y_reg_test, pred_Rfr))
print("R2_score on training Data:", r2_score(y_reg_train, pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_reg_test, pred_Rfr))
print("Mean Squared Error:", mean_squared_error(y_reg_test, pred_Rfr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg_test, pred_Rfr)))
# Out:
# R2_score: 0.5949219162987638
# R2_score on training Data: 94.12675502944981
# Mean Absolute Error: 7.779649857458743
# Mean Squared Error: 98.86691105365526
# Root Mean Squared Error: 9.943184150645871

# %%
Svr = SVR()
Svr.fit(X_reg_train, y_reg_train)
pred_Svr = Svr.predict(X_reg_test)
pred_train = Svr.predict(X_reg_train)

print("R2_score:", r2_score(y_reg_test, pred_Rfr))
print("R2_score on training Data:", r2_score(y_reg_train, pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_reg_test, pred_Svr))
print("Mean Squared Error:", mean_squared_error(y_reg_test, pred_Svr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg_test, pred_Svr)))
# Out:
# R2_score: 0.5949219162987638
# R2_score on training Data: 30.14080473867193
# Mean Absolute Error: 10.065737884544626
# Mean Squared Error: 159.00006842004706
# Root Mean Squared Error: 12.609522925949541

# %%
Knn = KNeighborsRegressor()
Knn.fit(X_reg_train, y_reg_train)
pred_Knn = Knn.predict(X_reg_test)
pred_train = Knn.predict(X_reg_train)

print("R2_score:", r2_score(y_reg_test, pred_Knn))
print("R2_score on training Data:", r2_score(y_reg_train, pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_reg_test, pred_Knn))
print("Mean Squared Error:", mean_squared_error(y_reg_test, pred_Knn))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg_test, pred_Knn)))
# Out:
# R2_score: 0.30848581712045575
# R2_score on training Data: 52.92915037168338
# Mean Absolute Error: 10.269431893396787
# Mean Squared Error: 168.77701846125416
# Root Mean Squared Error: 12.991420956202372

# %% [markdown]
# Cross validation

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(lr, X_reg, y_reg, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg_test, pred_lr) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [ 1.81998846e-01  1.55955579e-01  1.47174954e-04  1.91605003e-02
#  -1.86289483e-01]
# Mean Cross Validation Score: 0.03419452342272542
# Difference between R2 score and Cross Validation score: 33.085014313671934

# %%
scores = cross_val_score(Rd, X_reg, y_reg, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg_test, pred_Rd) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [ 0.18179607  0.15630008  0.00035187  0.01924871 -0.18546762]
# Mean Cross Validation Score: 0.03444582156851137
# Difference between R2 score and Cross Validation score: 33.05634734225662

# %%
scores = cross_val_score(Dtr, X_reg, y_reg, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg_test, pred_Dtr) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [-0.54167402 -0.13479923 -0.40123153 -0.83787644 -0.83059532]
# Mean Cross Validation Score: -0.5492353064837554
# Difference between R2 score and Cross Validation score: 68.14487831195528

# %%
scores = cross_val_score(Rfr, X_reg, y_reg, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg_test, pred_Rfr) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [0.25858559 0.39339716 0.40996804 0.27749776 0.22589636]
# Mean Cross Validation Score: 0.31306898147147766
# Difference between R2 score and Cross Validation score: 28.185293482728614

# %%
scores = cross_val_score(Svr, X_reg, y_reg, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg_test, pred_Svr) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [-0.11208012  0.22047138  0.08019777  0.18453732  0.12846492]
# Mean Cross Validation Score: 0.10031825419360582
# Difference between R2 score and Cross Validation score: 24.822573956984787

# %%
scores = cross_val_score(Knn, X_reg, y_reg, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg_test, pred_Knn) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [ 0.14785789  0.13624329 -0.0453542   0.05911267 -0.11844911]
# Mean Cross Validation Score: 0.035882107988203106
# Difference between R2 score and Cross Validation score: 27.260370913225263

# %% [raw]
# our best fit model is Rfr (RandomForestRegressor()) for "VOTES"

# %%
#GridSearchCV
from sklearn.model_selection import GridSearchCV

# %%
reg = RandomForestRegressor()

parameters = {
    "n_estimators": [100, 200, 300],
    "max_depth": [0, 5, 10],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "max_features": ["auto", "sqrt", "log2"]
}

grid = GridSearchCV(estimator=reg, param_grid=parameters, cv=5, n_jobs=-1)
grid.fit(X_reg_train, y_reg_train)

best_params = grid.best_params_
print("Best Parameters:", best_params)

score = grid.score(X_reg_test, y_reg_test)
print("Test Score:", score)
# Out:
# Best Parameters: {'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# Test Score: 0.5848905051439366

# %%
Model = RandomForestRegressor(max_depth=10, max_features='auto', min_samples_leaf=1, min_samples_split=5, n_estimators=100)

# %%
Model.fit(X_reg_train, y_reg_train)
pred = Model.predict(X_reg_test)

print("R2_score:", r2_score(y_reg_test, pred))
print("Mean Absolute Error:", mean_absolute_error(y_reg_test, pred))
print("Mean Squared Error:", mean_squared_error(y_reg_test, pred))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg_test, pred)))
# Out:
# R2_score: 0.5825742211644331
# Mean Absolute Error: 7.9107137686548095
# Mean Squared Error: 101.88059786042878
# Root Mean Squared Error: 10.093591920640975

# %%
#Save the model for Task 1(Votes)
import pickle

filename = 'IMDB_MOVIE_2023.pkl'
pickle.dump(Model, open(filename, 'wb'))

# %%
LoadedModel_Task1 = pickle.load(open('IMDB_MOVIE_2023.pkl', 'rb'))
result = LoadedModel_Task1.score(X_reg_test, y_reg_test)
print(result * 100)
# Out:
# 58.257422116443315

# %%
Conclusion = pd.DataFrame([LoadedModel_Task1.predict(X_reg_test)[:],y_reg_test[:]],index = ["predicted","Original"])
Conclusion
# Out:
#                  0          1          2          3          4          5    \
# predicted  41.049550  46.705640  37.447003  57.905392  34.577205  73.542046
# Original   50.219436  35.339552  30.500851  35.624177  39.894514  83.288828
#
#                  6          7          8          9    ...        521  \
# predicted  44.725294  69.490273  58.967608  41.821403  ...  44.053880
# Original   57.687379  76.302465  42.526627  29.309022  ...  39.077645
#
#                  522        523        524        525        526        527  \
# predicted  44.592083  50.170961  39.276070  47.687085  38.775772  38.298496
# Original   44.160399  59.852787  33.106482  37.509627  40.396882  30.887557
#
#                  528        529        530
# predicted  37.170209  42.589957  52.641527
# Original   30.753508  47.151016  30.468928
#
# [2 rows x 531 columns]

# %% [markdown]
# Regression TASK 2 (Gross Collection)

# %%
#Separating features and label
X_reg1 = df.drop("Gross Collection",axis=1)
y_reg1= df["Gross Collection"]

# %%
#Feature Scalling using standard scalarization
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_reg1 = pd.DataFrame(scaler.fit_transform(X_reg1), columns=X_reg1.columns)
X_reg1
# Out:
#            SNO  Movie Name  Director Name1  Director Name2  Director Name3  \
# 0     0.192821    0.606238       -0.318357        3.880193        8.770060
# 1     1.510822    0.567154        1.362761       -0.221420       -0.075798
# 2    -0.191849    0.484871       -1.788858       -0.221420       -0.075798
# 3    -0.169578    0.439616        0.298180       -0.221420       -0.075798
# 4    -0.149333    0.513670       -0.617053       -0.221420       -0.075798
# ...        ...         ...             ...             ...             ...
# 1765 -0.240439   -0.905705        1.312979       -0.221420       -0.075798
# 1766 -0.238414    0.591839       -0.448558       -0.221420       -0.075798
# 1767 -0.236390    0.809887        1.021942       -0.221420       -0.075798
# 1768 -0.234365   -1.442599       -0.295381       -0.221420       -0.075798
# 1769 -0.230316   -0.521034        1.561892       -0.221420       -0.075798
#
#       Duration      Year    Rating  Metascore  Stars Name1  Stars Name2  \
# 0    -0.065862  0.950304  2.786651   1.741858     1.182565    -0.554066
# 1     0.253859  0.759517  2.554550  -2.174505     1.317972     0.851991
# 2     1.090053 -3.247000  2.438500   2.288327     1.487231     1.411357
# 3    -0.238019 -2.929023  2.438500   1.696319     1.356660    -1.700308
# 4     0.475205  0.886708  2.438500  -2.174505    -0.906576     0.665535
# ...        ...       ...       ...        ...          ...          ...
# 1765  1.729496  0.632326 -3.015867  -2.174505     1.322808    -1.009506
# 1766 -0.533147 -0.703180 -3.015867  -1.127106     1.076173    -0.315648
# 1767  1.704902 -0.385202 -3.015867  -1.628036    -0.872724    -0.294251
# 1768 -0.434771 -0.703180 -3.131917  -0.899410    -1.467548    -0.624369
# 1769 -0.385583 -0.067224 -3.131917  -1.491418    -0.345603     1.099579
#
#       Stars Name3  Stars Name4     Votes    Genre1    Genre2    Genre3  \
# 0       -1.284820     0.269411  0.458465  4.873940 -1.024803 -1.341882
# 1       -1.441142     1.550361 -0.005201 -0.206669  0.783873 -1.536885
# 2        0.034643     1.692421  1.341444 -0.206669  0.783873 -1.536885
# 3        1.301115     1.432378 -0.615999 -0.206669  0.582909  0.608144
# 4        0.940780     1.360144 -0.624863 -0.206669  0.582909  0.608144
# ...           ...          ...       ...       ...       ...       ...
# 1765     1.685296    -0.281975 -1.073533 -0.206669  0.180981  0.608144
# 1766     1.656152     1.415524 -0.351087 -0.206669 -0.823839 -0.756874
# 1767     0.935481     1.085655 -1.228029 -0.206669 -0.220947  0.998149
# 1768    -1.706094     1.547953  0.910718 -0.206669  2.391585 -1.536885
# 1769     0.948729     0.156244 -0.783978 -0.206669 -0.823839 -0.171867
#
#       Popularity  Certification
# 0       2.785062       0.357428
# 1       2.553339       0.357428
# 2       2.437478       0.357428
# 3       2.437478      -2.868309
# 4       2.437478       0.357428
# ...          ...            ...
# 1765   -3.008014      -0.852223
# 1766   -3.008014       0.962254
# 1767   -3.008014      -0.045789
# 1768   -3.123875       0.357428
# 1769   -3.123875       0.962254
#
# [1770 rows x 19 columns]

# %%
#checking variance inflation factor (vif)
from statsmodels.stats.outliers_influence import variance_inflation_factor

Vif = pd.DataFrame()
Vif['VIF Values'] = [variance_inflation_factor(X_reg1.values, i) for i in range(len(X_reg1.columns))]
Vif['Features'] = X_reg1.columns
Vif
# Out:
#     VIF Values        Features
# 0     1.238858             SNO
# 1     1.009013      Movie Name
# 2     1.016345  Director Name1
# 3     1.169274  Director Name2
# 4     1.071904  Director Name3
# 5     1.069654        Duration
# 6     1.105466            Year
# 7    14.272639          Rating
# 8     1.364654       Metascore
# 9     1.013808     Stars Name1
# 10    1.015300     Stars Name2
# 11    1.012248     Stars Name3
# 12    1.019285     Stars Name4
# 13    1.430670           Votes
# 14    1.311797          Genre1
# 15    1.085165          Genre2
# 16    1.101082          Genre3
# 17   13.806235      Popularity
# 18    1.073193   Certification

# %%
y_reg1.value_counts()
# Out:
# 1316.0    287
# 3.0         8
# 1.0         7
# 4.0         5
# 5.0         5
#          ...
# 768.0       1
# 472.0       1
# 372.0       1
# 1120.0      1
# 838.0       1
# Name: Gross Collection, Length: 1317, dtype: int64

# %% [markdown]
# modelling for regression

# %%
#import liabraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
#finding the best random state

MaxAccu = 0
MaxRs = 0

for i in range(1, 200):
    X_reg1_train, X_reg1_test, y_reg1_train, y_reg1_test = train_test_split(X_reg1, y_reg1, test_size=0.3, random_state=i)
    lr = LinearRegression()
    lr.fit(X_reg1_train, y_reg1_train)
    pred = lr.predict(X_reg1_test)
    acc = r2_score(y_reg1_test, pred)
    if acc > MaxAccu:
        MaxAccu = acc
        MaxRs = i

print("Maximum R2 score is", MaxAccu, "on Random State", MaxRs)
# Out:
# Maximum R2 score is 0.07829477267285623 on Random State 58

# %%
X_reg1_train, X_reg1_test, y_reg1_train,y_reg1_test = train_test_split(X_reg1, y_reg1, test_size=0.3, random_state=58)

# %%
#modelling
#import liabraries
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

# %%
lr.fit(X_reg1_train,y_reg1_train)
pred_lr = lr.predict(X_reg1_test)
pred_train = lr.predict(X_reg1_train)

print("R2_score:",r2_score(y_reg1_test,pred_lr))
print("R2_score on training Data:",r2_score(y_reg1_train,pred_train)*100)
print ("MeanAbsoluteError:",mean_absolute_error(y_reg1_test,pred_lr))
print ("MeanSquaredError:",mean_squared_error(y_reg1_test,pred_lr))
print ("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_reg1_test,pred_lr)))
# Out:
# R2_score: 0.07829477267285623
# R2_score on training Data: 6.070439037884235
# MeanAbsoluteError: 362.539649877001
# MeanSquaredError: 174446.31670444558
# Root Mean Squared Error: 417.6677108712685

# %%
Rd = Ridge()
Rd.fit(X_reg1_train, y_reg1_train)
pred_Rd = Rd.predict(X_reg1_test)
pred_train = Rd.predict(X_reg1_train)

print("R2_score:", r2_score(y_reg1_test, pred_Rd))
print("R2_score on training Data:", r2_score(y_reg1_train, pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_reg1_test, pred_Rd))
print("Mean Squared Error:", mean_squared_error(y_reg1_test, pred_Rd))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg1_test, pred_Rd)))
# Out:
# R2_score: 0.07824330089676534
# R2_score on training Data: 6.070400426034139
# Mean Absolute Error: 362.5626806593876
# Mean Squared Error: 174456.05849768606
# Root Mean Squared Error: 417.6793728419995

# %%
Dtr = DecisionTreeRegressor()
Dtr.fit(X_reg1_train, y_reg1_train)
pred_Dtr = Dtr.predict(X_reg1_test)
pred_train = Dtr.predict(X_reg1_train)

print("R2_score:", r2_score(y_reg1_test, pred_Dtr))
print("R2_score on training Data:", r2_score(y_reg1_train, pred_train))
print("Mean Absolute Error:", mean_absolute_error(y_reg1_test, pred_Dtr))
print("Mean Squared Error:", mean_squared_error(y_reg1_test, pred_Dtr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg1_test, pred_Dtr)))
# Out:
# R2_score: -0.9185731386724401
# R2_score on training Data: 1.0
# Mean Absolute Error: 474.54802259887003
# Mean Squared Error: 363118.2806026365
# Root Mean Squared Error: 602.592964282389

# %%
Rfr = RandomForestRegressor()
Rfr.fit(X_reg1_train, y_reg1_train)
pred_Rfr = Rfr.predict(X_reg1_test)
pred_train = Rfr.predict(X_reg1_train)

print("R2_score:", r2_score(y_reg1_test, pred_Rfr))
print("R2_score on training Data:", r2_score(y_reg1_train, pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_reg1_test, pred_Rfr))
print("Mean Squared Error:", mean_squared_error(y_reg1_test, pred_Rfr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg1_test, pred_Rfr)))
# Out:
# R2_score: 0.10716844159849603
# R2_score on training Data: 87.74082853491815
# Mean Absolute Error: 347.1400564971751
# Mean Squared Error: 168981.5487455744
# Root Mean Squared Error: 411.0736536748304

# %%
Svr = SVR()
Svr.fit(X_reg1_train, y_reg1_train)
pred_Svr = Svr.predict(X_reg1_test)
pred_train = Svr.predict(X_reg1_train)

print("R2_score:", r2_score(y_reg1_test, pred_Rfr))
print("R2_score on training Data:", r2_score(y_reg1_train, pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_reg1_test, pred_Svr))
print("Mean Squared Error:", mean_squared_error(y_reg1_test, pred_Svr))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg1_test, pred_Svr)))
# Out:
# R2_score: 0.10716844159849603
# R2_score on training Data: 0.492904047277265
# Mean Absolute Error: 382.2479626431893
# Mean Squared Error: 188447.49219308342
# Root Mean Squared Error: 434.10539295553957

# %%
Knn = KNeighborsRegressor()
Knn.fit(X_reg1_train, y_reg1_train)
pred_Knn = Knn.predict(X_reg1_test)
pred_train = Knn.predict(X_reg1_train)

print("R2_score:", r2_score(y_reg1_test, pred_Knn))
print("R2_score on training Data:", r2_score(y_reg1_train, pred_train)*100)
print("Mean Absolute Error:", mean_absolute_error(y_reg1_test, pred_Knn))
print("Mean Squared Error:", mean_squared_error(y_reg1_test, pred_Knn))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg1_test, pred_Knn)))
# Out:
# R2_score: -0.11122502401275791
# R2_score on training Data: 24.62524988014999
# Mean Absolute Error: 390.14839924670434
# Mean Squared Error: 210315.73514124297
# Root Mean Squared Error: 458.60193538758966

# %% [markdown]
# CROSS VALIDATION SCORE

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(lr, X_reg1, y_reg1, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg1_test, pred_lr) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [ 0.07043962  0.06147628 -0.00262428  0.00846941  0.05002546]
# Mean Cross Validation Score: 0.03755729760116335
# Difference between R2 score and Cross Validation score: 4.073747507169288

# %%
scores = cross_val_score(Rd, X_reg1, y_reg1, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg1_test, pred_Rd) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [ 0.07051344  0.06158114 -0.00260763  0.00851614  0.04998675]
# Mean Cross Validation Score: 0.03759796771336179
# Difference between R2 score and Cross Validation score: 4.064533318340356

# %%
scores = cross_val_score(Dtr, X_reg1, y_reg1, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg1_test, pred_Dtr) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [-0.433378   -0.60932969 -0.8134122  -0.78764765 -1.02573911]
# Mean Cross Validation Score: -0.7339013287003331
# Difference between R2 score and Cross Validation score: -18.467180997210697

# %%
scores = cross_val_score(Rfr, X_reg1, y_reg1, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg1_test, pred_Rfr) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [0.16064073 0.10412412 0.03407248 0.06366349 0.12787975]
# Mean Cross Validation Score: 0.09807611398361035
# Difference between R2 score and Cross Validation score: 0.9092327614885681

# %%
scores = cross_val_score(Svr, X_reg1, y_reg1, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg1_test, pred_Svr) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [ 0.00296877 -0.0042365  -0.00497066 -0.01212851 -0.00478394]
# Mean Cross Validation Score: -0.00463016886675538
# Difference between R2 score and Cross Validation score: 0.8948277082624023

# %%
scores = cross_val_score(Svr, X_reg1, y_reg1, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg1_test, pred_Svr) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [ 0.00296877 -0.0042365  -0.00497066 -0.01212851 -0.00478394]
# Mean Cross Validation Score: -0.00463016886675538
# Difference between R2 score and Cross Validation score: 0.8948277082624023

# %%
scores = cross_val_score(Knn, X_reg1, y_reg1, cv=5)
print("Cross Validation Scores:", scores)
print("Mean Cross Validation Score:", scores.mean())
diff = r2_score(y_reg1_test, pred_Knn) - scores.mean()
print("Difference between R2 score and Cross Validation score:", diff * 100)
# Out:
# Cross Validation Scores: [-0.05862189 -0.03717673 -0.0853672  -0.15831536 -0.16718775]
# Mean Cross Validation Score: -0.10133378362776284
# Difference between R2 score and Cross Validation score: -0.9891240384995073

# %% [raw]
# our best fit model is Rfr (RandomForestRegressor()) for "Gross collection"

# %% [markdown]
# HyperparameterTuning

# %%
#GridSearchCV
from sklearn.model_selection import GridSearchCV

# %%
reg1 = RandomForestRegressor()

parameters = {
    "n_estimators": [100, 200, 300],
    "max_depth": [0, 5, 10],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "max_features": ["auto", "sqrt", "log2"]
}

grid = GridSearchCV(estimator=reg1, param_grid=parameters, cv=5, n_jobs=-1)
grid.fit(X_reg1_train, y_reg1_train)

best_params = grid.best_params_
print("Best Parameters:", best_params)

score = grid.score(X_reg1_test, y_reg1_test)
print("Test Score:", score)
# Out:
# Best Parameters: {'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 200}
# Test Score: 0.10923476440169577

# %%
Model1 = RandomForestRegressor(max_depth=10, max_features='auto', min_samples_leaf=1, min_samples_split=10, n_estimators=200)

# %%
Model1.fit(X_reg1_train, y_reg1_train)
pred = Model1.predict(X_reg1_test)

print("R2_score:", r2_score(y_reg1_test, pred))
print("Mean Absolute Error:", mean_absolute_error(y_reg1_test, pred))
print("Mean Squared Error:", mean_squared_error(y_reg1_test, pred))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_reg1_test, pred)))
# Out:
# R2_score: 0.10801283063163558
# Mean Absolute Error: 347.0365829755232
# Mean Squared Error: 168821.73565964453
# Root Mean Squared Error: 410.87922271592726

# %%
#Save the model for Task 2(Gross Collection)
import pickle

filename = 'IMDB_MOVIE_2023.pkl'
pickle.dump(Model1, open(filename, 'wb'))

# %%
LoadedModel_Task2 = pickle.load(open('IMDB_MOVIE_2023.pkl', 'rb'))
result = LoadedModel_Task2.score(X_reg1_test, y_reg1_test)
print(result * 100)
# Out:
# 10.801283063163558

# %%
Conclusion = pd.DataFrame([LoadedModel_Task2.predict(X_reg1_test)[:],y_reg1_test[:]],index = ["predicted","Original"])
Conclusion
# Out:
#                   0           1           2            3           4    \
# predicted  755.737302  552.474105  667.431434   880.511764  752.089804
# Original   599.000000  633.000000  536.000000  1316.000000  896.000000
#
#                   5           6           7            8           9    ...  \
# predicted  763.877527  807.711755  780.643654   699.803375  409.723189  ...
# Original    14.000000  175.000000  667.000000  1316.000000  688.000000  ...
#
#                   521         522         523         524          525  \
# predicted  600.061858  854.379568  882.598624   778.61569   605.733009
# Original   868.000000  788.000000  211.000000  1316.00000  1316.000000
#
#                    526          527          528         529         530
# predicted   870.252925   387.235311   696.198254  828.060202  713.319145
# Original   1316.000000  1316.000000  1113.000000  684.000000   16.000000
#
# [2 rows x 531 columns]
